# %% [markdown]
# ## SEP22_CATEGORIES_LOAD_BREAKDOWN
# - File type: xlsx
# - Description: Conversion of text files delimited by “|” and broken out into categories for ease of processing.
# - Sheets: ['ORIG', 'MIGRATION', 'OTHER', 'RSV', 'TAS', 'TDY', 'PCS', 'SEP']
# - Notes:
#     1. All the sheets add up to 1687 rows
#     2. All the sheets have 18 columns
#     3. The 'Orig' tab is 1683
#     4. Excluding 'other' all the sheets add up to 'orig'
#     5. All data is the same trhoughout the sheets
#     6. None of the the sheets have any headers
#     7. There are 8 sheets
#     8. 'Orig' has arifare and fee
#     9. 'Orig' is the master at first glance

# %% [markdown]
# ### 'ORIG' tab
# - number of columns (18)
# - number rows (1683)
# - data types (numbers and text)

# %%
#finding the sheet names
xls = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx', sheet_name = None)
print(xls.keys())
# Out:
# dict_keys(['ORIG', 'MIGRATION', 'OTHER', 'RSV', 'TAS', 'TDY', 'PCS', 'SEP'])

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='ORIG', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1683 entries, 0 to 1682
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CBA-092822               1683 non-null   object
#  1   20220928                 1683 non-null   int64
#  2   4486270011227540         1683 non-null   int64
#  3   578664.49                1683 non-null   float64
#  4   September CBA LOAD       1683 non-null   object
#  5   20220928.1               1683 non-null   int64
#  6   1                        1683 non-null   int64
#  7   5                        1683 non-null   float64
#  8   MCFALL/JOANNA L-AIRFARE  1683 non-null   object
#  9   Unnamed: 9               0 non-null      float64
#  10  Unnamed: 10              0 non-null      float64
#  11  Unnamed: 11              0 non-null      float64
#  12  Unnamed: 12              0 non-null      float64
#  13  70Z0TDY22103495-CBA      1683 non-null   object
# ...

# %%
df.head(20)
# Out:
#     CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 3   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 4   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 6   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 7   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 8   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 9   CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 10  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 11  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# ...

# %% [markdown]
# ### 'Migration' tab
# - number of columns (18)
# - number rows (3)
# - data types (numbers and text)
# - Notes:
#     1. only has 3 rows

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='MIGRATION', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CBA-092822               3 non-null      object
#  1   20220928                 3 non-null      int64
#  2   4486270011227540         3 non-null      int64
#  3   578664.49                3 non-null      float64
#  4   September CBA LOAD       3 non-null      object
#  5   20220928.1               3 non-null      int64
#  6   76                       3 non-null      int64
#  7   466.2                    3 non-null      float64
#  8   ADAMS/CHRISTINE-AIRFARE  3 non-null      object
#  9   Unnamed: 9               0 non-null      float64
#  10  Unnamed: 10              0 non-null      float64
#  11  Unnamed: 11              0 non-null      float64
#  12  Unnamed: 12              0 non-null      float64
#  13  1122232PXG123000-CBA     3 non-null      object
# ...

# %%
df
# Out:
#    CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
#
#    20220928.1    76   466.2     ADAMS/CHRISTINE-AIRFARE  Unnamed: 9  \
# 0    20220928    77    9.35         ADAMS/CHRISTINE-FEE         NaN
# 1    20220928  1672  338.49  GONZALEZ OTERO/MAX-AIRFARE         NaN
# 2    20220928  1673   37.63      GONZALEZ OTERO/MAX-FEE         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  1122232PXG123000-CBA  \
# 0          NaN          NaN          NaN  1122232PXG123000-CBA
# 1          NaN          NaN          NaN  1222G82PRA0F2000-CBA
# 2          NaN          NaN          NaN  1222G82PRA0F2000-CBA
#
#    1122232PXG123000  UCG  Unnamed: 16  CBA
# 0  1122232PXG123000  UCG          NaN  CBA
# 1  1222G82PRA0F2000  UCG          NaN  CBA
# ...

# %% [markdown]
# ### 'Other' tab
# - number of columns (18)
# - number rows (14)
# - data types (numbers and text)
# - Notes:
#     1. Has only 4 rows

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='OTHER', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CBA-092822           4 non-null      object
#  1   20220928             4 non-null      int64
#  2   4486270011227540     4 non-null      int64
#  3   578664.49            4 non-null      float64
#  4   September CBA LOAD   4 non-null      object
#  5   20220928.1           4 non-null      int64
#  6   270                  4 non-null      int64
#  7   37.63                4 non-null      float64
#  8   DUNN/STEVEN C-FEE    4 non-null      object
#  9   Unnamed: 9           0 non-null      float64
#  10  Unnamed: 10          0 non-null      float64
#  11  Unnamed: 11          0 non-null      float64
#  12  Unnamed: 12          0 non-null      float64
#  13  70Z0BLK22105367-CBA  4 non-null      object
#  14  70Z0BLK22105367      4 non-null      object
# ...

# %%
df.head()
# Out:
#    CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 3  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
#
#    20220928.1  270   37.63              DUNN/STEVEN C-FEE  Unnamed: 9  \
# 0    20220928  560  574.20  MAGANA/RICHARD MARTIN-AIRFARE         NaN
# 1    20220928  561   37.63      MAGANA/RICHARD MARTIN-FEE         NaN
# 2    20220928  645  576.01            CRUZ/LUIS E-AIRFARE         NaN
# 3    20220928  646   37.63                CRUZ/LUIS E-FEE         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12   70Z0BLK22105367-CBA  \
# 0          NaN          NaN          NaN  70Z0TSV220094388-CBA
# 1          NaN          NaN          NaN  70Z0TSV220094388-CBA
# ...

# %% [markdown]
# ### 'RSV' tab
# - number of columns (18)
# - number rows (5)
# - data types (numbers and text)
# - Notes:
#     1. Has only 5 rows

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='RSV', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CBA-092822                   5 non-null      object
#  1   20220928                     5 non-null      int64
#  2   4486270011227540             5 non-null      int64
#  3   578664.49                    5 non-null      float64
#  4   September CBA LOAD           5 non-null      object
#  5   20220928.1                   5 non-null      int64
#  6   386                          5 non-null      int64
#  7   724.2                        5 non-null      float64
#  8   HERNANDEZ/LINDSAY M-AIRFARE  5 non-null      object
#  9   Unnamed: 9                   0 non-null      float64
#  10  Unnamed: 10                  0 non-null      float64
#  11  Unnamed: 11                  0 non-null      float64
#  12  Unnamed: 12                  0 non-null      float64
# ...

# %%
df.head()
# Out:
#    CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 3  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 4  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
#
#    20220928.1   386   724.2 HERNANDEZ/LINDSAY M-AIRFARE  Unnamed: 9  \
# 0    20220928   387   37.63     HERNANDEZ/LINDSAY M-FEE         NaN
# 1    20220928   986  181.60   DEMACEDO/JOSHUA V-AIRFARE         NaN
# 2    20220928   987   37.63       DEMACEDO/JOSHUA V-FEE         NaN
# 3    20220928  1273  860.20     PARMAN/PAETYN E-AIRFARE         NaN
# 4    20220928  1274   37.63         PARMAN/PAETYN E-FEE         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  70Z0RSV220115638-CBA  \
# ...

# %% [markdown]
# ### 'TAS' tab
# - number of columns (18)
# - number rows (127)
# - data types (numbers and text)
# - Notes:
#     1. Only has 127 rows

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='TAS', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CBA-092822                        127 non-null    object
#  1   20220928                          127 non-null    int64
#  2   4486270011227540                  127 non-null    int64
#  3   578664.49                         127 non-null    float64
#  4   September CBA LOAD                127 non-null    object
#  5   20220928.1                        127 non-null    int64
#  6   40                                127 non-null    int64
#  7   35.53                             127 non-null    float64
#  8   KVITSINSKI/ANDREI ANDREEVICH-FEE  127 non-null    object
#  9   Unnamed: 9                        0 non-null      float64
#  10  Unnamed: 10                       0 non-null      float64
# ...

# %%
df.head()
# Out:
#    CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 3  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 4  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
#
#    20220928.1   40   35.53      KVITSINSKI/ANDREI ANDREEVICH-FEE  Unnamed: 9  \
# 0    20220928   56   35.53                      WEBB/CAVIN M-FEE         NaN
# 1    20220928  135  138.51        ATKINSON/COLTON EDWARD-AIRFARE         NaN
# 2    20220928  136  775.09             NELSON/DREW SCOTT-AIRFARE         NaN
# 3    20220928  141  259.04  ENCARNACION OCASIO/ANGEL LEO-AIRFARE         NaN
# 4    20220928  207  518.20        DUKES III/URIEL PIERCE-AIRFARE         NaN
#
# ...

# %% [markdown]
# ### 'TDY' tab
# - number of columns (18)
# - number rows (1294)
# - data types (numbers and text)
# - Notes:
#     1. Has 1294 rows

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='TDY', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294 entries, 0 to 1293
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CBA-092822               1294 non-null   object
#  1   20220928                 1294 non-null   int64
#  2   4486270011227540         1294 non-null   int64
#  3   578664.49                1294 non-null   float64
#  4   September CBA LOAD       1294 non-null   object
#  5   20220928.1               1294 non-null   int64
#  6   1                        1294 non-null   int64
#  7   5                        1294 non-null   float64
#  8   MCFALL/JOANNA L-AIRFARE  1294 non-null   object
#  9   Unnamed: 9               0 non-null      float64
#  10  Unnamed: 10              0 non-null      float64
#  11  Unnamed: 11              0 non-null      float64
#  12  Unnamed: 12              0 non-null      float64
#  13  70Z0TDY22103495-CBA      1294 non-null   object
# ...

# %%
df.head()
# Out:
#    CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 3  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 4  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
#
#    20220928.1   1       5    MCFALL/JOANNA L-AIRFARE  Unnamed: 9  Unnamed: 10  \
# 0    20220928   8  216.00  FREEMAN/RICHARD W-AIRFARE         NaN          NaN
# 1    20220928   9  209.00    DONALDSON/BLAKE-AIRFARE         NaN          NaN
# 2    20220928  10  148.50    DONALDSON/BLAKE-AIRFARE         NaN          NaN
# 3    20220928  11   35.53          COPPIN/CHAD R-FEE         NaN          NaN
# 4    20220928  12   35.53   GRAY/GARRETT MICHAEL-FEE         NaN          NaN
#
# ...

# %% [markdown]
# ### 'PCS' tab
# - number of columns (18)
# - number rows (179)
# - data types (numbers and text)
# - Notes:
#     1. Only has 179 rows

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='PCS', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CBA-092822                    179 non-null    object
#  1   20220928                      179 non-null    int64
#  2   4486270011227540              179 non-null    int64
#  3   578664.49                     179 non-null    float64
#  4   September CBA LOAD            179 non-null    object
#  5   20220928.1                    179 non-null    int64
#  6   3                             179 non-null    int64
#  7   592                           179 non-null    float64
#  8   BOWERS/ZACHARY TYLER-AIRFARE  179 non-null    object
#  9   Unnamed: 9                    0 non-null      float64
#  10  Unnamed: 10                   0 non-null      float64
#  11  Unnamed: 11                   0 non-null      float64
# ...

# %%
df.head()
# Out:
#    CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 3  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 4  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
#
#    20220928.1   3      592        BOWERS/ZACHARY TYLER-AIRFARE  Unnamed: 9  \
# 0    20220928   4   528.00         FRIEND/STEVEN TYLER-AIRFARE         NaN
# 1    20220928   5  2633.00  JOHNSON/ELIJAH ANTHONY LEE-AIRFARE         NaN
# 2    20220928   6  2174.00            LAMANSKY/ETHAN J-AIRFARE         NaN
# 3    20220928  13    35.53            COLLINS/JESSE O NEAL-FEE         NaN
# 4    20220928  14    35.53                HOSKINSON/HAEDEN-FEE         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  70Z0PCS220060096-CBA  \
# ...

# %% [markdown]
# ### 'SEP' tab
# - number of columns (18)
# - number rows (65)
# - data types (numbers and text)
# - Notes:
#     1. Only has 65 rows

# %%
df = pd.read_excel('./SEP22_CATEGORIES_LOAD_BREAKDOWN.xlsx',sheet_name='SEP', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CBA-092822                65 non-null     object
#  1   20220928                  65 non-null     int64
#  2   4486270011227540          65 non-null     int64
#  3   578664.49                 65 non-null     float64
#  4   September CBA LOAD        65 non-null     object
#  5   20220928.1                65 non-null     int64
#  6   2                         65 non-null     int64
#  7   1467                      65 non-null     float64
#  8   PHILLIPS/ANTHONY-AIRFARE  65 non-null     object
#  9   Unnamed: 9                0 non-null      float64
#  10  Unnamed: 10               0 non-null      float64
#  11  Unnamed: 11               0 non-null      float64
#  12  Unnamed: 12               0 non-null      float64
# ...

# %%
df.head()
# Out:
#    CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD  \
# 0  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 1  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 2  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 3  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 4  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
#
#    20220928.1   2    1467 PHILLIPS/ANTHONY-AIRFARE  Unnamed: 9  Unnamed: 10  \
# 0    20220928   7  264.00     ARCAND/ETHAN-AIRFARE         NaN          NaN
# 1    20220928  21   35.53     RODD/ESTHER MARY-FEE         NaN          NaN
# 2    20220928  22   35.53         PORTER/DAVIN-FEE         NaN          NaN
# 3    20220928  23   35.53       PORTER/DEAGLAN-FEE         NaN          NaN
# 4    20220928  25   35.53        HOGAN/KELLY A-FEE         NaN          NaN
#
# ...
