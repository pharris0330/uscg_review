# %% [markdown]
# ## USCG MAIN 7547__09-28-22_UPDATE
# - File type: xlsx
# - Description: Detailed airline invoice information
# - Sheets: ['Sheet1']
# - Notes:
#     1. 27 columns and 2568 rows
#     2. No duplicate ref #'s b/t uscg main and sato

# %%
xls = pd.read_excel('./USCG MAIN 7547__09-28-22_UPDATE.xlsx', sheet_name = None)
print(xls.keys())
# Out:
# dict_keys(['Sheet1'])

# %%
import pandas as pd
df = pd.read_excel('./USCG MAIN 7547__09-28-22_UPDATE.xlsx', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2568 entries, 0 to 2567
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Period End Date             2560 non-null   object
#  1   Airline Code                2535 non-null   object
#  2   Ticket Number               2548 non-null   float64
#  3   Reservation Number          2533 non-null   object
#  4   Passenger Name              2548 non-null   object
#  5   Invoice Date                2548 non-null   datetime64[ns]
#  6   Invoice Number              2547 non-null   object
#  7   Invoice Amount              2561 non-null   float64
#  8   Depart Date                 2551 non-null   object
#  9   Trip End Date               2548 non-null   object
#  10  Routing                     2419 non-null   object
#  11  CC Reference Number         2548 non-null   object
#  12  PO Number                   2463 non-null   object
# ...

# %%
df.head()
# Out:
#        Period End Date Airline Code  Ticket Number Reservation Number  \
# 0  2022-09-28 00:00:00          738   7.785661e+09             ZHTGUN
# 1  2022-09-28 00:00:00          006   7.785661e+09             ISNPFZ
# 2  2022-09-28 00:00:00          001   7.782916e+09             ISNPFZ
# 3  2022-09-28 00:00:00          006   7.785661e+09             ISNPFZ
# 4  2022-09-28 00:00:00          526   7.788841e+09             WSOGZF
#
#             Passenger Name Invoice Date Invoice Number  Invoice Amount  \
# 0  ABBOTT/MITCHELL RAYMOND   2022-08-26        0072069           39.19
# 1        ABEL/RYAN MICHAEL   2022-08-26        0072195           37.63
# 2        ABEL/RYAN MICHAEL   2022-09-04        0068339         -362.10
# 3        ABEL/RYAN MICHAEL   2022-08-26        0072195          363.60
# 4           ABEL/VINCENT P   2022-09-12        0076510          398.20
#
#            Depart Date        Trip End Date  ... Minor Code     Trip ID  \
# ...

# %%
import pandas as pd
df_sato = pd.read_excel('./SEP22_SatoMain4327.xls', index_col=None)

# %%
test_ref = df_sato['Reference']

# %%
test_ref2 = df['CC Reference Number']

# %%
df_ref = test_ref + test_ref2
df_ref = df_ref.to_frame()

# %%
df_ref2 = df_ref.duplicated(keep=False)
df_ref2 = df_ref2.to_frame()

# %%
ref_df.tail(40)
# Out:
#        0_x   0_y
# 12386  NaN  True
# 12387  NaN  True
# 12388  NaN  True
# 12389  NaN  True
# 12390  NaN  True
# 12391  NaN  True
# 12392  NaN  True
# 12393  NaN  True
# 12394  NaN  True
# 12395  NaN  True
# 12396  NaN  True
# 12397  NaN  True
# 12398  NaN  True
# 12399  NaN  True
# 12400  NaN  True
# 12401  NaN  True
# 12402  NaN  True
# 12403  NaN  True
# 12404  NaN  True
# 12405  NaN  True
# 12406  NaN  True
# 12407  NaN  True
# 12408  NaN  True
# 12409  NaN  True
# 12410  NaN  True
# 12411  NaN  True
# 12412  NaN  True
# 12413  NaN  True
# 12414  NaN  True
# 12415  NaN  True
# 12416  NaN  True
# 12417  NaN  True
# 12418  NaN  True
# 12419  NaN  True
# 12420  NaN  True
# 12421  NaN  True
# 12422  NaN  True
# 12423  NaN  True
# 12424  NaN  True
# 12425  NaN  True

# %%
df_ref2_none = df

# %%
ref_df = pd.merge(df_ref, df_ref2, left_index=True, right_index=True)

# %%
ref_df
# Out:
#                                                   0_x    0_y
# 0      7461402224223510001452824717052239582391136699  False
# 1      7461402224223510001453624717052239582391155269  False
# 2      7461402224223510001454474943002252344700053398  False
# 3      7461402224223510001455124717052239872393660337  False
# 4      7461402224223510001456924692162256104532333202  False
# ...                                               ...    ...
# 12421                                             NaN   True
# 12422                                             NaN   True
# 12423                                             NaN   True
# 12424                                             NaN   True
# 12425                                             NaN   True
#
# [12426 rows x 2 columns]

# %%
ref_df_true = ref_df['0_y'] == True

# %%
new = ref_df[ref_df_true]

# %%
new
# Out:
#        0_x   0_y
# 26     NaN  True
# 27     NaN  True
# 29     NaN  True
# 30     NaN  True
# 32     NaN  True
# ...    ...   ...
# 12421  NaN  True
# 12422  NaN  True
# 12423  NaN  True
# 12424  NaN  True
# 12425  NaN  True
#
# [11372 rows x 2 columns]

# %%
new['0_x'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 26       NaN
# 27       NaN
# 29       NaN
# 30       NaN
# 32       NaN
#         ...
# 12421    NaN
# 12422    NaN
# 12423    NaN
# 12424    NaN
# 12425    NaN
# Name: 0_x, Length: 11372, dtype: object>

# %%
ytrue = ref_df['0_y'] == True

# %%
test = ref_df[ytrue] == None
ref_df[~test]
# Out:
#        0_x   0_y
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ...    ...   ...
# 12421  NaN  True
# 12422  NaN  True
# 12423  NaN  True
# 12424  NaN  True
# 12425  NaN  True
#
# [12426 rows x 2 columns]

# %%
ref_df = df_ref.merge(df_ref2)
ref_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\PAULHA~1\AppData\Local\Temp/ipykernel_13360/2138833431.py in <module>
# ----> 1 ref_df = df_ref.merge(df_ref2)
#       2 ref_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ...
