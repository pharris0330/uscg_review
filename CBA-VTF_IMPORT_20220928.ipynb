# %% [markdown]
# ## CBA-VTF_IMPORT_20220928
# - File type: xlsx
# - Description: ....
# - Sheets: ['Report', 'UPLOAD']
# - Notes:
#     1. 2 sheets
#     2. 'Report' has all the 'Upload' accounts
#     3. Bowyer Quinn is repeated but description is incorrect

# %% [markdown]
# ## To do:
# - connection b/t uscg main update and CBT
# - check names
# - screen shots
# - check counts
# - shared columns

# %%
import pandas as pd
xls = pd.read_excel('./CBA-VTF_IMPORT_20220928_.xlsx', sheet_name = None)
print(xls.keys())
# Out:
# dict_keys(['Report', 'UPLOAD'])

# %% [markdown]
# ### 'Report' tab
# - number of columns (XX)
# - number rows (XX)
# - data types (XX)
# - Notes:
#     1. Many of the columns have repeat data
#     2. Boyer/ Quinn is the only line description

# %%
import pandas as pd
df = pd.read_excel('./CBA-VTF_IMPORT_20220928_.xlsx',sheet_name='Report', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2482 entries, 0 to 2481
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ACCOUNT              2482 non-null   int64
#  1   TOTAL                2482 non-null   float64
#  2   INV DESC             2482 non-null   object
#  3   CYCLE DATE           2482 non-null   int64
#  4   FEE AMOUNT           2482 non-null   float64
#  5   FINAL_APPROVAL_DATE  2482 non-null   datetime64[ns]
#  6   FEE_TRANSMIT_DATE    2482 non-null   datetime64[ns]
#  7   LINE DESCRIPTION     2482 non-null   object
#  8   CBA PO NUMBER        2482 non-null   object
#  9   PO NUMBER            2482 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(4)
# memory usage: 194.0+ KB

# %%
df.head()
# Out:
#             ACCOUNT     TOTAL                     INV DESC  CYCLE DATE  \
# 0  4486270011227547  39111.63  VTF CBA LOAD SEPTEMBER 2022    20220928
# 1  4486270011227547  39111.63  VTF CBA LOAD SEPTEMBER 2022    20220928
# 2  4486270011227547  39111.63  VTF CBA LOAD SEPTEMBER 2022    20220928
# 3  4486270011227547  39111.63  VTF CBA LOAD SEPTEMBER 2022    20220928
# 4  4486270011227547  39111.63  VTF CBA LOAD SEPTEMBER 2022    20220928
#
#    FEE AMOUNT FINAL_APPROVAL_DATE FEE_TRANSMIT_DATE  \
# 0       16.05          2022-08-22        2022-08-23
# 1       16.05          2022-08-22        2022-08-23
# 2       16.05          2022-08-22        2022-08-23
# 3       16.05          2022-08-22        2022-08-23
# 4       16.05          2022-08-22        2022-08-23
#
#                   LINE DESCRIPTION         CBA PO NUMBER         PO NUMBER
# 0  BOWYER/QUINN-VTF FEE 12303965-1  70Z0RSV220079129-CBA  70Z0RSV220079129
# ...

# %% [markdown]
# ### 'Upload' tab
# - number of columns (XX)
# - number rows (XX)
# - data types (XX)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_excel('./CBA-VTF_IMPORT_20220928_.xlsx',sheet_name='UPLOAD', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2481 entries, 0 to 2480
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                          --------------  -----
#  0   CBA-VTF-09282022|20220928|4486270011227547|0000039111.63|VTF CBA LOAD SEPTEMBER 2022|20220928|1|0000000016.05|LARSON/ERIC-VTF FEE 12113312|||||70Z0PCS220093808-CBA|70Z0PCS220093808|UCG||CBA|  2481 non-null   object
# dtypes: object(1)
# memory usage: 19.5+ KB

# %%
df.head()
# Out:
#   CBA-VTF-09282022|20220928|4486270011227547|0000039111.63|VTF CBA LOAD SEPTEMBER 2022|20220928|1|0000000016.05|LARSON/ERIC-VTF FEE 12113312|||||70Z0PCS220093808-CBA|70Z0PCS220093808|UCG||CBA|
# 0  CBA-VTF-09282022|20220928|4486270011227547|000...
# 1  CBA-VTF-09282022|20220928|4486270011227547|000...
# 2  CBA-VTF-09282022|20220928|4486270011227547|000...
# 3  CBA-VTF-09282022|20220928|4486270011227547|000...
# 4  CBA-VTF-09282022|20220928|4486270011227547|000...
