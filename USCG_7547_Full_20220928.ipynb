# %% [markdown]
# ## USCG_7547_Full_20220928
# - File type: xlsx
# - Description: Compilation of all the monthly line items in one sheet, incorporating file type, some updates, VTF, and other items.
# - Sheets: ['USCG_7547_Full_20220928']
# - Notes:
#     1. Has only 1 sheet
#     2. Same columns as 'SEP22 CATEGORIES AND....' + 2 more
#         - Names, Sep. CBA Load, etc
#     3. Has the headers not found in 'SEP22 Catergories and....'
#     4. 20 columns and 5037 rows

# %%
import pandas as pd
xls = pd.read_excel('./USCG_7547_Full_20220928.xlsx', sheet_name = None)
print(xls.keys())
# Out:
# dict_keys(['USCG_7547_Full_20220928'])

# %%
import pandas as pd
df = pd.read_excel('./USCG_7547_Full_20220928.xlsx', index_col=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5037 entries, 0 to 5036
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Column1     5037 non-null   object
#  1   Column2     5037 non-null   int64
#  2   Column3     5037 non-null   int64
#  3   Column4     5037 non-null   float64
#  4   Month       5037 non-null   object
#  5   Date        5037 non-null   int64
#  6   Column5     5037 non-null   int64
#  7   Amount      5037 non-null   float64
#  8   Name        5035 non-null   object
#  9   Last Name   1 non-null      object
#  10  First Name  0 non-null      float64
#  11  Middle      0 non-null      float64
#  12  Trans Type  0 non-null      float64
#  13  CBA PO      4479 non-null   object
#  14  PO          4944 non-null   object
#  15  Column10    5037 non-null   object
#  16  Column11    0 non-null      float64
#  17  File        5037 non-null   object
#  18  Pay Y/N     0 non-null      float64
# ...

# %%
df.tail(20)
# Out:
#          Column1   Column2           Column3    Column4               Month  \
# 5017  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5018  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5019  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5020  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5021  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5022  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5023  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5024  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5025  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5026  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# 5027  CBA-092822  20220928  4486270011227540  578664.49  September CBA LOAD
# ...

# %%
df['File'].value_counts()
# Out:
# DB_PO_ERRORS    3220
# TDY             1295
# PCS              180
# TAS              128
# CREDIT            94
# SEP               66
# CR_PO_ERRORS      39
# RSV                6
# OTH                5
# MIG                4
# Name: File, dtype: int64
